# %% [markdown]
# # Bài tập lập trình: Tiền xử lý dữ liệu
#
# ```
# ProtonX - TensorFlow Class
# ```
#
# ### Hướng dẫn làm bài
# - Trong bài tập này bạn sẽ sử dụng Python 3.
# - Sau khi bạn viết Code của mình xong, hãy chạy dòng Code đó để xem kết quả bên dưới.
#
# ### [Quan trọng] Chú ý
# - **Không sử dụng hàm `input()` tại bất kỳ dòng lệnh nào**
# - **Không thay đổi dòng code return của hàm**
#
# Các bạn sẽ thực hiện `code` trong các phần hiển thị `#TODO: Lập trình tại đây` và thay thế các vị trí `None`. Có những câu hỏi chỉ cần trả về đáp án.
#
# Sau khi viết xong Code của bạn, bạn hãy ấn "SHIFT"+"ENTER" để thực hiện chạy lệnh của Cell đó.
#
# ---
# Điểm số:
# * 10 điểm / Câu
#
# Tiêu chí chấm điểm:
# * Các bài tập sẽ được chấm dựa trên các Test-case.
# * Các bạn không khởi tạo lại giá trị đầu vào bên trong hàm. Có thể khởi tạo các giá trị này ngoài hàm nhằm mục đích kiểm thử.

# %%
# !pip install tensorflow_data_validation
# Out:
# Requirement already satisfied: tensorflow_data_validation in /usr/local/lib/python3.10/dist-packages (1.14.0)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.4.0)
# Requirement already satisfied: apache-beam[gcp]<3,>=2.47 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (2.52.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.3.2)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.23.5)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.5.3)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (3.20.3)
# Requirement already satisfied: pyarrow<11,>=10 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (10.0.1)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (0.3.2)
# Requirement already satisfied: six<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.16.0)
# Requirement already satisfied: tensorflow<3,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (2.15.0)
# Requirement already satisfied: tensorflow-metadata<1.15,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.14.0)
# Requirement already satisfied: tfx-bsl<1.15,>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.14.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.9.10)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.9.1)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.60.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (4.19.2)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (4.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.23.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2023.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.22.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.6)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (5.3.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.11.1)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.17.3)
# Requirement already satisfied: google-auth-httplib2<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.1.1)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.15.2)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.19.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.9.0)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.12.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.24.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.3.3)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.22.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.40.1)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.14.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.9.1)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.12.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.5.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.10.6)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.38.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (0.34.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.13->tensorflow_data_validation) (2.15.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata<1.15,>=1.14.0->tensorflow_data_validation) (1.62.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.15,>=1.14.0->tensorflow_data_validation) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.15,>=1.14.0->tensorflow_data_validation) (2.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13->tensorflow_data_validation) (0.42.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.15,>=1.14.0->tensorflow_data_validation) (3.0.1)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (4.9)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.8.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.11.0)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.0.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.13.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.48.2)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (7.4.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.4.4)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.13.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (2023.11.17)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (3.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (1.3.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47->tensorflow_data_validation) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3,>=2.13->tensorflow_data_validation) (3.2.2)

# %% [markdown]
# ## 0. Cài đặt các thư viện cần thiết

# %%
import pandas as pd
import tensorflow as tf
import tensorflow_data_validation as tfdv
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

# %% [markdown]
# ## 1. Tải dữ liệu

# %%
# !wget https://storage.googleapis.com/protonx-cloud-storage/datasets/credit_risk/train.csv
# !wget https://storage.googleapis.com/protonx-cloud-storage/datasets/credit_risk/validation.csv
# Out:
# --2023-12-17 17:21:07--  https://storage.googleapis.com/protonx-cloud-storage/datasets/credit_risk/train.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.0.91, 172.217.12.27, 172.217.15.251, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.0.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38013 (37K) [application/octet-stream]
# Saving to: ‘train.csv.1’
#
# train.csv.1         100%[===================>]  37.12K  --.-KB/s    in 0s
#
# 2023-12-17 17:21:07 (118 MB/s) - ‘train.csv.1’ saved [38013/38013]
#
# --2023-12-17 17:21:07--  https://storage.googleapis.com/protonx-cloud-storage/datasets/credit_risk/validation.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.0.91, 172.217.12.27, 172.217.15.251, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.0.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22699 (22K) [application/octet-stream]
# Saving to: ‘validation.csv.1’
#
# validation.csv.1    100%[===================>]  22.17K  --.-KB/s    in 0s
#
# 2023-12-17 17:21:07 (54.8 MB/s) - ‘validation.csv.1’ saved [22699/22699]

# %% [markdown]
# ## 2. Đọc dữ liệu
#
# Đây là bộ dữ liệu cho vay, bao gồm những thuộc tính quyết định một tổ chức có nên cho một cá nhân vay tín dụng hay không.
#
# **a. Các đặc trưng để quyết định (Loại trừ đặc trưng Loan_ID)**
# - Gender (Giới tính)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `Male` hoặc `Female`
# - Married (Tình trạng hôn nhân)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `Yes` hoặc `No`
# - Dependents (Số lượng người phụ thuộc trong gia đình)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `0` hoặc `1` hoặc `2` hoặc `3+`
# - Education (Học vấn)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `Graduate` hoặc `Not Graduate`
# - Self_Employed (Có tự làm chủ không)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `Yes` hoặc `No`
# - ApplicantIncome (Thu nhập người vay)
#   - Dạng: Số
#   - Đặc trưng số liên tục
# - CoapplicantIncome (Thu nhập người cùng đi vay)
#   - Dạng: Số
#   - Đặc trưng số liên tục
# - LoanAmount (Số tiền vay)
#   - Dạng: Số
#   - Đặc trưng số liên tục
# - Loan_Amount_Term (Kỳ hạn)
#   - Dạng: Số
#   - Đặc trưng số liên tục
# - Property_Area (Vị trí tài sản)
#   - Dạng: Chuỗi
#   - Đặc trưng loại: `Semiurban`, `Urban`, `Rural`
# - Credit_History (Lịch sử vay)
#   - Dạng: Số
#   - Đặc trưng số rời rạc: `1.0` hoặc `0.0`
#
# **b. Nhãn: Khả năng có nên cho vay hay không?**
# - Với file `train.cvs`
#   - Nhãn sử dụng dưới tên cột: `Loan_Status`
# - Với file `validation.cvs`
#   - Nhãn sử dụng dưới tên cột: `outcome`

# %%
train_df = pd.read_csv('train.csv')
val_df = pd.read_csv('validation.csv')

# %% [markdown]
# Hiển thị dữ liệu của tập train và validation

# %%
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
val_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area outcome
# 0             1.0         Urban       Y
# 1             1.0         Urban       Y
# 2             1.0         Urban       Y
# 3             NaN         Urban       Y
# 4             1.0         Urban       N

# %% [markdown]
# Hiển thị các giá trị của loại trong một cột bất kỳ

# %%
train_df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %% [markdown]
# ## 3. Hiển thị thống kê của dữ liệu

# %% [markdown]
# Chúng ta sẽ sử dụng thư viện `tensorflow_data_validation` để trích xuất thông tin thống kê của dữ liệu và hiển thị thông tin.

# %%
def display_stats(df):
  test_stats = tfdv.generate_statistics_from_dataframe(train_df)
  tfdv.visualize_statistics(test_stats)

# %% [markdown]
# Hiển thị thống kê của dữ liệu train

# %%
display_stats(train_df)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# Hiển thị thống kê của dữ liệu validation

# %% [markdown]
# ## 4. Đổi tên cột nhãn của bộ validation.
# Đổi tên từ `outcome` thành `Loan_Status`

# %%
val_df = val_df.rename(columns={'outcome': 'Loan_Status'})

# %% [markdown]
# Kiểm tra việc đổi tên

# %%
'Loan_Status' in val_df.columns and 'outcome' not in val_df.columns
# Out:
# True

# %% [markdown]
# ## 5. Kiểm tra các cột bị thiếu giá trị

# %% [markdown]
# Những cột thiếu giá trị trong tập train:
# - Đặc trưng loại: `Gender`, `Married`, `Dependents`, `Self_Employed`
# - Đặc trưng số liên tục: `LoanAmount`, `Loan_Amount_Term`
# - Đặc trưng số rời rạc: `Credit_History`

# %%
train_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# Những cột thiếu giá trị trong tập validation:
# - Đặc trưng loại: `Gender`, `Dependents`, `Self_Employed`
# - Đặc trưng số liên tục: `LoanAmount`, `Loan_Amount_Term`
# - Đặc trưng số rời rạc: `Credit_History`

# %%
val_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## 6. Xử lý dữ liệu bị thiếu (missing values)
#
# Trong bài này ta sử dụng một cách đơn giản để bổ sung các giá trị bị thiếu. Với
# - Đặc trưng loại: Bổ sung giá trị bị thiếu bằng giá trị xuất hiện nhiều nhất trong cột
# - Đặc trưng số liên tục: Bổ sung giá trị bị thiếu bằng giá trị trung bình (mean) của các giá trị trong cột
# - Đặc trưng số rời rạc: Bổ sung giá trị bị thiếu bằng giá trị xuất hiện nhiều nhất trong cột

# %% [markdown]
# **Chú ý:** Việc đổ đầy các giá trị thông qua giá trị nhiều nhất cũng như trung bình sẽ ảnh hưởng đến phân phối dữ liệu, nên trong phân tích việc này chỉ hiệu quả khi nguyên nhân thiếu hụt là `MCAR` (Missing Completely At Random) do một sự kiện đặc biệt nào đó và hoàn toàn không liên quan tới đặc trưng hiện tại cũng như các đặc trưng khác trong bộ dữ liệu.
#
# Chi tiết về thiếu dữ liệu - các nguyên nhân và giải pháp sẽ được đề cập chi tiết trong một buổi học của ProtonX.

# %% [markdown]
# ### 6.1 Xử lý đặc trưng loại bị thiếu.
# Bổ sung giá trị bị thiếu bằng giá trị xuất hiện nhiều nhất trong cột

# %% [markdown]
# Ví dụ cột `Gender` ta đổ đầy các giá trị thiếu bằng giá trị xuất hiện nhiều nhất.
#
# Hàm kiểm tra giá trị xuất hiện nhiều nhất

# %%
most_frequent_gender = train_df['Gender'].mode()[0]
most_frequent_gender
# Out:
# 'Male'

# %% [markdown]
# Sử dụng hàm `fillna` để đổ đầy các giá trị thiếu bằng giá trị này

# %%
train_df['Gender'] = train_df['Gender'].fillna(most_frequent_gender)

# %% [markdown]
# Kiểm tra lại cột `Gender` còn giá trị thiếu hay không?

# %%
train_df['Gender'].isna().sum()
# Out:
# 0

# %% [markdown]
# ```TODO 1:``` Đóng gói một hàm có khả năng đổ đầy thông tin cho đặc trưng loại bằng giá trị xuất hiện nhiều nhất trong cột

# %%
def fill_categorical_features(df, column_name):
  """
  Đầu vào:
    - df:
      - Dạng: Pandas DataFrame.
      - Ví dụ: train_df, val_df, test_df
    - column_name:
      - Miêu tả: Tên cột đặc trưng loại muốn đổ đầy các giá trị thiếu bằng giá trị xuất hiện nhiều nhất trong cột
      - Điều kiện: len(column_name) > 0
      - Ví dụ: 'Gender'
  Đầu ra:
    - Trả về Dataframe đã được đổ đầy thông tin trong cột
  """
  # Lập trình tại đây

  # Tìm ra giá trị xuất hiện nhiều nhất trong cột
  if df[column_name].notna().any():
    # Tìm ra giá trị xuất hiện nhiều nhất trong cột
    most_frequent_value = df[column_name].mode()[0]

    # Điền giá trị xuất hiện nhiều nhất vào những ô trống
    df[column_name] = df[column_name].fillna(most_frequent_value)

  return df

# %% [markdown]
# ```TODO 2```: Thực hiện hàm này trên các cột thiếu của tập train: `Gender`, `Married`, `Dependents`, `Self_Employed`

# %%
train_df = fill_categorical_features(train_df, 'Gender')
train_df = fill_categorical_features(train_df, 'Married')
train_df = fill_categorical_features(train_df, 'Dependents')
train_df = fill_categorical_features(train_df, 'Self_Employed')

# %%
# TEST CODE
columns = ['Gender', 'Married', 'Dependents', 'Self_Employed']
for col in columns:
  print("Số lượng còn thiếu ở cột {} là: {}".format(col, train_df[col].isna().sum()))
  print("Số lượng các giá trị hiện tại của cột {} là".format(col, ))
  print(train_df[col].value_counts())
  print('----------------------------------------------------')
# Out:
# Số lượng còn thiếu ở cột Gender là: 0
# Số lượng các giá trị hiện tại của cột Gender là
# Male      502
# Female    112
# Name: Gender, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Married là: 0
# Số lượng các giá trị hiện tại của cột Married là
# Yes    401
# No     213
# Name: Married, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Dependents là: 0
# Số lượng các giá trị hiện tại của cột Dependents là
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Self_Employed là: 0
# Số lượng các giá trị hiện tại của cột Self_Employed là
# No     532
# Yes     82
# Name: Self_Employed, dtype: int64
# ----------------------------------------------------

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Số lượng còn thiếu ở cột Gender là: 0
# Số lượng các giá trị hiện tại của cột Gender là
# Male      502
# Female    112
# Name: Gender, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Married là: 0
# Số lượng các giá trị hiện tại của cột Married là
# Yes    401
# No     213
# Name: Married, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Dependents là: 0
# Số lượng các giá trị hiện tại của cột Dependents là
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Self_Employed là: 0
# Số lượng các giá trị hiện tại của cột Self_Employed là
# No     532
# Yes     82
# Name: Self_Employed, dtype: int64
# ----------------------------------------------------
# ```

# %% [markdown]
# ```TODO 3```: Thực hiện hàm này trên các cột thiếu của tập validation: `Gender`, `Dependents`, `Self_Employed`

# %%
# Lập trình tại đây
val_df = fill_categorical_features(val_df, 'Gender')
val_df = fill_categorical_features(val_df, 'Dependents')
val_df = fill_categorical_features(val_df, 'Self_Employed')

# %%
# TEST CODE
columns = ['Gender', 'Dependents', 'Self_Employed']
for col in columns:
  print("Số lượng còn thiếu ở cột {} là: {}".format(col, val_df[col].isna().sum()))
  print("Số lượng các giá trị hiện tại của cột {} là".format(col, ))
  print(val_df[col].value_counts())
  print('----------------------------------------------------')
# Out:
# Số lượng còn thiếu ở cột Gender là: 0
# Số lượng các giá trị hiện tại của cột Gender là
# Male      297
# Female     70
# Name: Gender, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Dependents là: 0
# Số lượng các giá trị hiện tại của cột Dependents là
# 0     210
# 2      59
# 1      58
# 3+     40
# Name: Dependents, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Self_Employed là: 0
# Số lượng các giá trị hiện tại của cột Self_Employed là
# No     330
# Yes     37
# Name: Self_Employed, dtype: int64
# ----------------------------------------------------

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Số lượng còn thiếu ở cột Gender là: 0
# Số lượng các giá trị hiện tại của cột Gender là
# Male      297
# Female     70
# Name: Gender, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Dependents là: 0
# Số lượng các giá trị hiện tại của cột Dependents là
# 0     210
# 2      59
# 1      58
# 3+     40
# Name: Dependents, dtype: int64
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Self_Employed là: 0
# Số lượng các giá trị hiện tại của cột Self_Employed là
# No     330
# Yes     37
# Name: Self_Employed, dtype: int64
# ----------------------------------------------------
# ```

# %% [markdown]
# ### 6.2 Xử lý đặc trưng số liên tục bị thiếu.
# Bổ sung giá trị bị thiếu bằng giá trị trung bình (mean) của các giá trị trong cột

# %% [markdown]
# Ví dụ cột `LoanAmount` ta đổ đầy các giá trị thiếu bằng giá trị trung bình (mean) của các giá trị trong cột này
#
# Hàm tìm giá trị trung bình trong một cột

# %%
mean_loan_amount = train_df['LoanAmount'].mean()
mean_loan_amount
# Out:
# 146.41216216216216

# %% [markdown]
# Sử dụng hàm `fillna` để đổ đầy các giá trị thiếu bằng giá trị này

# %%
train_df['LoanAmount'] = train_df['LoanAmount'].fillna(mean_loan_amount)

# %% [markdown]
# Kiểm tra lại cột `LoanAmount` còn giá trị thiếu hay không?

# %%
train_df['LoanAmount'].isna().sum()
# Out:
# 0

# %% [markdown]
# ```TODO 4:``` Đóng gói một hàm có khả năng đổ đầy thông tin cho đặc trưng số liên tục bằng giá trị trung bình trong cột

# %%
def fill_continuous_numerical_features(df, column_name):
  """
  Đầu vào:
    - df:
      - Dạng: Pandas DataFrame.
      - Ví dụ: train_df, val_df, test_df
    - column_name:
      - Miêu tả: Tên cột đặc trưng loại muốn đổ đầy các giá trị thiếu bằng bằng giá trị trung bình trong cột
      - Điều kiện: len(column_name) > 0
      - Ví dụ: 'LoanAmount'
  Đầu ra:
    - Trả về Dataframe đã được đổ đầy thông tin trong cột
  """
  # Lập trình tại đây

  # Tìm ra giá trị trung bình trong cột
  if df[column_name].notna().any():
    # Tìm ra giá trị xuất hiện nhiều nhất trong cột
    mean_value = df[column_name].mean()

    # Điền giá trị xuất hiện nhiều nhất vào những ô trống
    df[column_name] = df[column_name].fillna(mean_value)

  return df

# %% [markdown]
# ```TODO 5```: Thực hiện hàm này trên các cột thiếu của tập train: `LoanAmount`, `Loan_Amount_Term`

# %%
# Lập trình tại đây
train_df = fill_continuous_numerical_features(train_df, 'LoanAmount')
train_df = fill_continuous_numerical_features(train_df, 'Loan_Amount_Term')

# %%
# TEST CODE
columns = ['LoanAmount', 'Loan_Amount_Term']
for col in columns:
  print("Số lượng còn thiếu ở cột {} là: {}".format(col, train_df[col].isna().sum()))
  print("Giá trị trung bình mới: {}".format(train_df[col].mean()))
  print('----------------------------------------------------')
# Out:
# Số lượng còn thiếu ở cột LoanAmount là: 0
# Giá trị trung bình mới: 146.41216216216216
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Loan_Amount_Term là: 0
# Giá trị trung bình mới: 342.0
# ----------------------------------------------------

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Số lượng còn thiếu ở cột LoanAmount là: 0
# Giá trị trung bình mới: 146.41216216216213
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Loan_Amount_Term là: 0
# Giá trị trung bình mới: 342.0
# ----------------------------------------------------
# ```

# %% [markdown]
# ```TODO 6```: Thực hiện hàm này trên các cột thiếu của tập validation: `LoanAmount`, `Loan_Amount_Term`

# %%
# Lập trình tại đây
val_df = fill_continuous_numerical_features(val_df, 'LoanAmount')
val_df = fill_continuous_numerical_features(val_df, 'Loan_Amount_Term')

# %%
# TEST CODE
columns = ['LoanAmount', 'Loan_Amount_Term']
for col in columns:
  print("Số lượng còn thiếu ở cột {} là: {}".format(col, val_df[col].isna().sum()))
  print("Giá trị trung bình mới: {}".format(val_df[col].mean()))
  print('----------------------------------------------------')
# Out:
# Số lượng còn thiếu ở cột LoanAmount là: 0
# Giá trị trung bình mới: 136.13259668508286
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Loan_Amount_Term là: 0
# Giá trị trung bình mới: 342.53739612188366
# ----------------------------------------------------

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Số lượng còn thiếu ở cột LoanAmount là: 0
# Giá trị trung bình mới: 136.27264526106487
# ----------------------------------------------------
# Số lượng còn thiếu ở cột Loan_Amount_Term là: 0
# Giá trị trung bình mới: 342.5286103542234
# ----------------------------------------------------
# ```

# %% [markdown]
# ### 6.3 Xử lý đặc trưng số rời rạc bị thiếu.
# Bổ sung giá trị bị thiếu bằng giá trị xuất hiện nhiều nhất trong cột. Ta có thể sử dụng lại hàm ```fill_categorical_features``` cho đặc trưng này

# %% [markdown]
# Thực hiện hàm này trên cột thiếu của tập train: `Credit_History`

# %%
train_df = fill_categorical_features(train_df, 'Credit_History')

# %% [markdown]
# Thực hiện hàm này trên cột thiếu của tập validation: `Credit_History`

# %%
val_df = fill_categorical_features(val_df, 'Credit_History')

# %% [markdown]
# ## 7. Chuẩn hóa các cột

# %% [markdown]
# ### 7.1 Viết hàm chuẩn hóa

# %% [markdown]
# Hàm chuẩn hóa này sẽ có thể chuẩn hóa dữ liệu theo phân phối chuẩn hoặc sử dụng minmax scale

# %%
def scaling(df, scaler, column_names, mode='train'):
  """
  Đầu vào:
    - df:
      - Dạng: Pandas DataFrame.
      - Ví dụ: train_df, val_df, test_df
    - scaler:
      - Dạng: đối tượng được tạo bởi Scaler bởi sklearn.
      - Ví dụ: StandardScaler() hoặc MinMaxScaler()
    - column_names:
      - Dạng: mảng Python chứa tên các cột muốn chuẩn hóa.
      - Ví dụ: ['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome']
      - Điều kiện: len(column_names) > 0
    - mode: Chế độ chuẩn hóa
      - Dạng: chuỗi Python
      - Ví dụ: một trong 3 giá trị {'train', 'val', 'test'}
  Đầu ra:
    - Trả về Dataframe đã được chuẩn hóa
  """
  # Nếu mode không hợp lệ thì báo lỗi
  assert mode in ['train', 'val', 'test'], 'Mode chỉ có thể nhận 3 giá trị nằm trong {train, val, test}'

  # Truy xuất các cột
  x = df[column_names].values

  # Nếu chế độ train thì tìm các thông số của phân phối và chuẩn hóa
  if mode == 'train':
    x_scaled = scaler.fit_transform(x)

  # Nếu chế độ là val hoặc test thì dùng các tham số để chuẩn hóa
  else:
    x_scaled = scaler.transform(x)

  # Tạo dataframe con cho các dữ liệu đã được chuẩn hóa
  normalized_features = pd.DataFrame(x_scaled, columns=column_names, index = df.index)

  # Gán lại dataframe con này cho dataframe lớn ban đầu
  df[column_names] = normalized_features

  return df

# %% [markdown]
# ### 7.2 Chuẩn hóa cho tập train

# %% [markdown]
# Thực hiện chuẩn hóa theo min max cho 4 cột `LoanAmount`, `ApplicantIncome`, `CoapplicantIncome`, `Loan_Amount_Term` của tập train

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

column_names_to_normalize =  ['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term']
train_df = scaling(train_df, min_max_scaler, column_names_to_normalize, mode='train')

# %% [markdown]
# Hiện thị các phân phối này

# %%
def display_distribution(df, features):
  plt.figure(figsize=(12,28*4))
  gs = gridspec.GridSpec(28, 1)
  for i, cn in enumerate(features):
      ax = plt.subplot(gs[i])
      sns.distplot(df[cn][df.Loan_Status == 'Y'], bins=50)
      sns.distplot(df[cn][df.Loan_Status == 'N'], bins=50)
      ax.set_xlabel('')
      ax.set_title('histogram of feature: ' + str(cn))
  plt.show()

# %% [markdown]
# Bạn có thể thắc mắc tại sao lại không sử dụng chuẩn hóa về phân phối chuẩn đơn vị (StandardScaler) thì trong trường hợp này các giá trị ví dụ `LoanAmount` đều là số dương cho nên chúng ta sẽ không ưu tiên sử dụng phân phối này - phân phối này tạo ra những `giá trị âm` bên trái trung bình 0. Có thể dùng phân phối `LogNormal` để thay thế.

# %%
columns_to_display = ['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome']
display_distribution(train_df, columns_to_display)
# Out:
# <ipython-input-71-c0aa31936b6e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'Y'], bins=50)
# <ipython-input-71-c0aa31936b6e>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'N'], bins=50)
# <ipython-input-71-c0aa31936b6e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'Y'], bins=50)
# <ipython-input-71-c0aa31936b6e>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'N'], bins=50)
# <ipython-input-71-c0aa31936b6e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'Y'], bins=50)
# <ipython-input-71-c0aa31936b6e>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[cn][df.Loan_Status == 'N'], bins=50)

# %% [markdown]
# ### 7.3 Chuẩn hóa cho tập validation

# %% [markdown]
# `TODO 7`: Sử dụng tham số min max của tập train để chuẩn hóa cho 4 cột `Loan_Amount_Term`, `LoanAmount`, `ApplicantIncome`, `CoapplicantIncome` của tập validation

# %%
column_names_to_normalize =  ['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term']

val_df = scaling(val_df, min_max_scaler, column_names_to_normalize, mode='val')

# %%
val_df['LoanAmount'].mean()
# Out:
# 0.18398349737349187

# %%
# TEST CODE
# Lập trình tại đây
columns = ['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term']
for col in columns:
  print("Giá trị trung bình của cột {} mới là : {}".format(col, val_df[col].mean()))
# Out:
# Giá trị trung bình của cột LoanAmount mới là : 0.18398349737349187
# Giá trị trung bình của cột ApplicantIncome mới là : 0.05758317198566323
# Giá trị trung bình của cột CoapplicantIncome mới là : 0.037669562403718757
# Giá trị trung bình của cột Loan_Amount_Term mới là : 0.7062764874399222

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Giá trị trung bình của cột LoanAmount mới là : 0.18418617259198974
# Giá trị trung bình của cột ApplicantIncome mới là : 0.05758317198566323
# Giá trị trung bình của cột CoapplicantIncome mới là : 0.037669562403718757
# Giá trị trung bình của cột Loan_Amount_Term mới là : 0.7062577144321035
# ```

# %% [markdown]
# ## 8. Số hóa các đặc trưng loại

# %% [markdown]
# Danh sách các cột đặc trưng loại.
# - Gender
# - Married
# - Dependents
# - Education
# - Self_Employed
# - Property_Area
# - Loan_Status

# %% [markdown]
# ### 8.1 Định nghĩa danh sách chuyển đặc trưng loại thành số tương ứng

# %% [markdown]
# Ta định nghĩa một từ điển lồng trong từ điển định nghĩa những giá trị tương ứng khi ta số hóa.
#
# Ví dụ:
# - Cột `Gender` các giá trị có thể là `Male` và `Female` ta sẽ chuyển thành `0` và `1`
# - Cột `Dependents` các giá trị có thể là chuỗi `'0'`, `'1'`, `'2'`, `'3+'` ta chuyển thành số `0`, `1`, `2`, `3`

# %%
categorical_to_number = {
    'Gender': {
        'Male': 0,
        'Female': 1,
    },
    'Married': {
        'Yes': 1,
        'No': 0
    },
    'Dependents': {
      '0': 0,
      '1': 1,
      '2': 2,
      '3+': 3,
    },
    'Education': {
        'Not Graduate': 0,
        'Graduate': 1,
    },
    'Self_Employed': {
        'No': 0,
        'Yes': 1,
    },
    'Property_Area': {
        'Rural': 0,
        'Urban': 1,
        'Semiurban': 2,
    },
    'Loan_Status': {
        'N': 0,
        'Y': 1,
    }

}

# %% [markdown]
# ### 8.2 Tiến hành chuyển đặc trưng loại thành số trên tập train

# %% [markdown]
# Hàm để chuyển một cột từ loại thành số. Ví dụ với cột `Gender`
#
# ```train_df['Gender'].map( {'Male': 0, 'Female': 1} ).astype(int)```

# %% [markdown]
# Thay vì chạy hàm này trên từng cột thì ta `lặp` qua từng cột tập `train` và sử dụng hàm này

# %%
for col in categorical_to_number:
  alternative_values = categorical_to_number[col]
  train_df[col] =  train_df[col].map( alternative_values ).astype(int)

# %% [markdown]
# Giờ ta có thể kiểm tra tất cả các cột đã được số hóa giá trị

# %%
train_df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       0        0           0          1              0
# 1  LP001003       0        1           1          1              0
# 2  LP001005       0        1           0          1              1
# 3  LP001006       0        1           0          0              0
# 4  LP001008       0        0           0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         0.070489           0.000000    0.198860           0.74359
# 1         0.054830           0.036192    0.172214           0.74359
# 2         0.035250           0.000000    0.082489           0.74359
# 3         0.030093           0.056592    0.160637           0.74359
# 4         0.072356           0.000000    0.191027           0.74359
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              1            1
# 1             1.0              0            0
# 2             1.0              1            1
# 3             1.0              1            1
# 4             1.0              1            1

# %% [markdown]
# ### 8.3 Tiến hành chuyển đặc trưng loại thành số trên tập validation

# %% [markdown]
# `TODO 8`: Số hóa các cột tương tự với tập validation, sử dụng từ điển `categorical_to_number` bên trên

# %%
for col in categorical_to_number:
  alternative_values = categorical_to_number[col]
  val_df[col] = val_df[col].map( alternative_values ).astype(int)

# %%
# TEST CODE
columns = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
for col in columns:
  print("Cột {} có kiểu mới là: {}".format(col, val_df[col].dtype))
# Out:
# Cột Gender có kiểu mới là: int64
# Cột Married có kiểu mới là: int64
# Cột Dependents có kiểu mới là: int64
# Cột Education có kiểu mới là: int64
# Cột Self_Employed có kiểu mới là: int64
# Cột Property_Area có kiểu mới là: int64
# Cột Loan_Status có kiểu mới là: int64

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# Cột Gender có kiểu mới là: int64
# Cột Married có kiểu mới là: int64
# Cột Dependents có kiểu mới là: int64
# Cột Education có kiểu mới là: int64
# Cột Self_Employed có kiểu mới là: int64
# Cột Property_Area có kiểu mới là: int64
# Cột Loan_Status có kiểu mới là: int64
# ```

# %% [markdown]
# ## 9. Xóa cột

# %% [markdown]
# ### 9.1 Trên tập train Xóa cột `Loan_ID`. Sử dụng cột `Loan_Status` làm nhãn

# %%
train_Y = train_df['Loan_Status']
train_X = train_df.drop(['Loan_ID', 'Loan_Status'], axis=1)

# %% [markdown]
# ### 9.2 Trên tập validation Xóa cột `Loan_ID`. Sử dụng cột `Loan_Status` làm nhãn

# %%
val_Y = val_df['Loan_Status']
val_X = val_df.drop(['Loan_ID', 'Loan_Status'], axis=1)

# %% [markdown]
# ## 10. Hiển thị ma trận tương quan

# %% [markdown]
# ### 10.1 Hệ số tương quan

# %% [markdown]
# Hệ số tương quan là một chỉ số đo lường của một số loại tương quan, nghĩa là mối liên hệ thống kê giữa hai biến số.

# %% [markdown]
# $$r =\frac{ \sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y}) }{
#         \sqrt{\sum_{i=1}^{n}(x_i-\bar{x})^2}\sqrt{\sum_{i=1}^{n}(y_i-\bar{y})^2}}
# $$

# %% [markdown]
# $\bar{x}$: Trung bình các giá trị $x$ \
# $\bar{y}$: Trung bình các giá trị $y$ \
# $r \in [-1, 1]$

# %% [markdown]
# Nhận xét:
# - Khi mối tương quan này nhỏ hơn 0, đồng nghĩa mối quan hệ nghịch biến, khi biến này tăng thì biến kia giảm và ngược lại
# - Khi mối tương quan này lớn hơn 0, đồng nghĩa mối quan hệ đồng biến, khi biến này tăng thì biến kia tăng và khi biến này giảm thì biến kia giảm
# - Khi mối tương quan này bằng 0, 2 biến không có quan hệ với nhau.

# %% [markdown]
# ### 10.2 Tương quan trên tập train

# %% [markdown]
# Hiển thị ma trận tương quan. Ma trận này hiển thị tất cả các giá trị tương quan giữa các cột dữ liệu với nhau. Trong thực tế, việc hiển thị này thường để xác định các cặp đặc trưng tương quan mạnh với nhau từ đó đưa ra quyết định `không sử dụng` một trong 2 đặc trưng để xây dựng mô hình.

# %%
train_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-83-03a6b367b717>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <ipython-input-83-03a6b367b717>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   train_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_249af_row0_col0, #T_249af_row1_col1, #T_249af_row2_col2, #T_249af_row3_col3, #T_249af_row4_col4, #T_249af_row5_col5, #T_249af_row6_col6, #T_249af_row7_col7, #T_249af_row8_col8, #T_249af_row9_col9, #T_249af_row10_col10, #T_249af_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_249af_row0_col1, #T_249af_row0_col2, #T_249af_row0_col7, #T_249af_row1_col0, #T_249af_row1_col8, #T_249af_row2_col3, #T_249af_row2_col8, #T_249af_row2_col9, #T_249af_row5_col6, #T_249af_row6_col5, #T_249af_row6_col11, #T_249af_row7_col10, #T_249af_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_249af_row0_col3, #T_249af_row9_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_249af_row0_col4, #T_249af_row9_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_249af_row0_col5, #T_249af_row4_col11, #T_249af_row5_col11, #T_249af_row8_col6, #T_249af_row11_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_249af_row0_col6, #T_249af_row0_col9, #T_249af_row2_col10, #T_249af_row11_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_249af_row0_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_249af_row0_col10, #T_249af_row11_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_249af_row0_col11, #T_249af_row1_col4, #T_249af_row1_col10, #T_249af_row4_col9, #T_249af_row6_col8, #T_249af_row7_col9, #T_249af_row8_col9, #T_249af_row8_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_249af_row1_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_249af_row1_col3, #T_249af_row3_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_249af_row1_col5, #T_249af_row10_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_249af_row1_col6, #T_249af_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_249af_row1_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_249af_row1_col9, #T_249af_row5_col8, #T_249af_row6_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_249af_row1_col11, #T_249af_row7_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_249af_row2_col0, #T_249af_row3_col11 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_249af_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_249af_row2_col4, #T_249af_row9_col5, #T_249af_row10_col5, #T_249af_row10_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_249af_row2_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_249af_row2_col6, #T_249af_row8_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_249af_row2_col7 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_249af_row2_col11, #T_249af_row4_col3, #T_249af_row8_col5, #T_249af_row11_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_249af_row3_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_249af_row3_col1, #T_249af_row9_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_249af_row3_col2, #T_249af_row11_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_249af_row3_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_249af_row3_col6, #T_249af_row3_col8, #T_249af_row11_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_249af_row3_col7, #T_249af_row5_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_249af_row3_col9, #T_249af_row6_col3, #T_249af_row9_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_249af_row3_col10, #T_249af_row4_col6, #T_249af_row9_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_249af_row4_col0, #T_249af_row6_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_249af_row4_col1, #T_249af_row7_col6, #T_249af_row10_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_249af_row4_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_249af_row4_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_249af_row4_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_249af_row4_col8, #T_249af_row8_col2, #T_249af_row9_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_249af_row4_col10, #T_249af_row5_col9, #T_249af_row7_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_249af_row5_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_249af_row5_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_249af_row5_col3, #T_249af_row10_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_249af_row5_col4, #T_249af_row11_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_249af_row5_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_249af_row5_col10, #T_249af_row6_col10 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_249af_row6_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_249af_row6_col1, #T_249af_row8_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_249af_row6_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_249af_row7_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_249af_row7_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_249af_row7_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_249af_row7_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_249af_row7_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_249af_row7_col8, #T_249af_row8_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_249af_row8_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_249af_row8_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_249af_row9_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_249af_row9_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_249af_row9_col6, #T_249af_row10_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_249af_row9_col11 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_249af_row10_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_249af_row10_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_249af_row10_col7, #T_249af_row10_col9, #T_249af_row11_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_249af_row10_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_249af_row11_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_249af_row11_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_249af_row11_col9 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# </style>
# <table id="T_249af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_249af_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_249af_level0_col1" class="col_heading level0 col1" >Married</th>
#       <th id="T_249af_level0_col2" class="col_heading level0 col2" >Dependents</th>
#       <th id="T_249af_level0_col3" class="col_heading level0 col3" >Education</th>
#       <th id="T_249af_level0_col4" class="col_heading level0 col4" >Self_Employed</th>
#       <th id="T_249af_level0_col5" class="col_heading level0 col5" >ApplicantIncome</th>
#       <th id="T_249af_level0_col6" class="col_heading level0 col6" >CoapplicantIncome</th>
#       <th id="T_249af_level0_col7" class="col_heading level0 col7" >LoanAmount</th>
#       <th id="T_249af_level0_col8" class="col_heading level0 col8" >Loan_Amount_Term</th>
#       <th id="T_249af_level0_col9" class="col_heading level0 col9" >Credit_History</th>
#       <th id="T_249af_level0_col10" class="col_heading level0 col10" >Property_Area</th>
#       <th id="T_249af_level0_col11" class="col_heading level0 col11" >Loan_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_249af_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_249af_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_249af_row0_col1" class="data row0 col1" >-0.36</td>
#       <td id="T_249af_row0_col2" class="data row0 col2" >-0.17</td>
#       <td id="T_249af_row0_col3" class="data row0 col3" >0.05</td>
#       <td id="T_249af_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_249af_row0_col5" class="data row0 col5" >-0.06</td>
#       <td id="T_249af_row0_col6" class="data row0 col6" >-0.08</td>
#       <td i

# %% [markdown]
# ### Phân tích:
#   - Với tập train có sự tương quan giữa số lượng vay (LoanAmount) và thu nhập người vay (ApplicantIncome). Tuy nhiên sự tương quan này chưa quá lớn để bỏ một trong 2 đặc trưng.
#   - Lịch sử vay (Credit_History) có sự tương quan tới khả năng được vay. Điều này hoàn toàn hợp lý
#
# ### Quyết định
#   - Giữ nguyên tất cả những đặc trưng cho việc training

# %% [markdown]
# ### 10.3 Tương quan trên tập Validation

# %% [markdown]
# Bạn hay tự đưa ra quan sát cá nhân của mình. (Đây không phải bài tập)

# %%
val_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-84-3b48e2f5a920>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   val_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <ipython-input-84-3b48e2f5a920>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   val_df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_24cd2_row0_col0, #T_24cd2_row1_col1, #T_24cd2_row2_col2, #T_24cd2_row3_col3, #T_24cd2_row4_col4, #T_24cd2_row5_col5, #T_24cd2_row6_col6, #T_24cd2_row7_col7, #T_24cd2_row8_col8, #T_24cd2_row9_col9, #T_24cd2_row10_col10, #T_24cd2_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col1, #T_24cd2_row0_col7, #T_24cd2_row1_col0, #T_24cd2_row2_col3, #T_24cd2_row3_col2, #T_24cd2_row4_col10, #T_24cd2_row5_col6, #T_24cd2_row6_col5, #T_24cd2_row6_col9, #T_24cd2_row8_col11, #T_24cd2_row10_col4, #T_24cd2_row11_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col2, #T_24cd2_row9_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col3, #T_24cd2_row6_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col4, #T_24cd2_row10_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col5, #T_24cd2_row6_col10, #T_24cd2_row7_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col6, #T_24cd2_row0_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col8, #T_24cd2_row2_col0, #T_24cd2_row4_col7, #T_24cd2_row11_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col10, #T_24cd2_row1_col11, #T_24cd2_row3_col1, #T_24cd2_row5_col11 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_24cd2_row0_col11, #T_24cd2_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_24cd2_row1_col3, #T_24cd2_row6_col2, #T_24cd2_row6_col8, #T_24cd2_row7_col11 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col4 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col5, #T_24cd2_row4_col9, #T_24cd2_row5_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col7, #T_24cd2_row3_col0, #T_24cd2_row5_col2, #T_24cd2_row5_col3, #T_24cd2_row6_col1, #T_24cd2_row7_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_24cd2_row1_col8, #T_24cd2_row3_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col9, #T_24cd2_row4_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_24cd2_row1_col10, #T_24cd2_row2_col4, #T_24cd2_row8_col6, #T_24cd2_row11_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_24cd2_row2_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col6, #T_24cd2_row10_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col7, #T_24cd2_row9_col4, #T_24cd2_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col10, #T_24cd2_row4_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_24cd2_row2_col11, #T_24cd2_row5_col8, #T_24cd2_row8_col10 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col5, #T_24cd2_row11_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col6, #T_24cd2_row7_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col9, #T_24cd2_row3_col10 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_24cd2_row3_col11, #T_24cd2_row10_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col0, #T_24cd2_row8_col7, #T_24cd2_row9_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col1, #T_24cd2_row7_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col5, #T_24cd2_row6_col3, #T_24cd2_row7_col8, #T_24cd2_row11_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col6, #T_24cd2_row10_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col8, #T_24cd2_row9_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_24cd2_row4_col11 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_24cd2_row5_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_24cd2_row5_col1, #T_24cd2_row7_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_24cd2_row5_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_24cd2_row5_col7 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_24cd2_row5_col10, #T_24cd2_row8_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_24cd2_row6_col4, #T_24cd2_row7_col10, #T_24cd2_row8_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_24cd2_row6_col7 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_24cd2_row6_col11, #T_24cd2_row8_col2, #T_24cd2_row9_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_24cd2_row7_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_24cd2_row7_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_24cd2_row7_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_24cd2_row8_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_24cd2_row8_col1, #T_24cd2_row9_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_24cd2_row8_col3, #T_24cd2_row11_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_24cd2_row8_col9 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_24cd2_row9_col0, #T_24cd2_row9_col5, #T_24cd2_row11_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_24cd2_row9_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_24cd2_row9_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_24cd2_row9_col11 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_24cd2_row10_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_24cd2_row10_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_24cd2_row10_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_24cd2_row10_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_24cd2_row10_col11 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_24cd2_row11_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_24cd2_row11_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_24cd2_row11_col9 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_24cd2_row11_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_24cd2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24cd2_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_24cd2_level0_col1" class="col_heading level0 col1" >Married</th>
#       <th id="T_24cd2_level0_col2" class="col_heading level0 col2" >Dependents</th>
#       <th id="T_24cd2_level0_col3" class="col_heading level0 col3" >Education</th>
#       <th id="T_24cd2_level0_col4" class="col_heading level0 col4" >Self_Employed</th>
#       <th id="T_24cd2_level0_col5" class="col_heading level0 col5" >ApplicantIncome</th>
#       <th id="T_24cd2_level0_col6" class="col_heading level0 col6" >CoapplicantIncome</th>
#       <th id="T_24cd2_level0_col7" class="col_heading level0 col7" >LoanAmount</th>
#       <th id="T_24cd2_level0_col8" class="col_heading level0 col8" >Loan_Amount_Term</th>
#       <th id="T_24cd2_level0_col9" class="col_heading level0 col9" >Credit_History</th>
#       <th id="T_24cd2_level0_col10" class="col_heading level0 col10" >Property_Area</th>
#       <th id="T_24cd2_level0_col11" class="col_heading level0 col11" >Loan_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24cd2_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_24cd2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_24cd2_row0_col1" class="data row0 col1" >-0.27</td>
#       <td id="T_24cd2_row0_col2" class="data row0 col2" >-0.09</td>
#       <td id="T_24cd2_row0_col3" class="data row0 col3" >0.03</td>
#       <td id="T_24cd2_row0_col4" class="data row0 col4" >-0.07</td>
#       <td id="T_24cd2_row0_col5" class="data row0 col5" >-0.06</td>
#       <td id="T_24cd2_row0_col6" class="data row0 col6" >-0.08</td>
#       <td

# %% [markdown]
# ## 11. Tiến hành xây dựng mô hình Logistic bằng Tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ```TODO 9```: Xây dựng mô hình Logistic

# %%
def create_model(input_shape):
  """
  Đầu vào:
    - input_shape:
      - Dạng: Tuple.
      - Ví dụ: (20, )
  Đầu ra:
    - model
      - Sequential model
  """
  # Lập trình tại đây
  # Tạo sequential model
  model = Sequential()

  # Thêm lớp Dense với đầu ra là 1 kèm theo activation là sigmoid. chiều đầu vào là tham số input_shape
  model.add(Dense(1, activation='sigmoid', input_shape=input_shape))

  # Trả về model
  return model

# %%
# TEST CODE
test_input_shape = (train_X.shape[1], )
test_model = create_model(input_shape=test_input_shape)
test_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 12
#
# =================================================================
# Total params: 12 (48.00 Byte)
# Trainable params: 12 (48.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Kết quả mong đợi:**
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 12
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %%
# Khởi tạo mô hình
learning_rate = 0.01
input_shape = (train_X.shape[1], )
model = create_model(input_shape=input_shape)

# %%
# Tạo optimizer sgd với tốc độ học là tham số learning_rate của hàm
sgd = SGD(learning_rate)

model.compile(sgd, loss='binary_crossentropy', metrics=['acc'])

# %%
model.fit(train_X, train_Y, epochs=200, verbose=2, validation_data=(val_X, val_Y))
# Out:
# Epoch 1/200
# 20/20 - 1s - loss: 0.6787 - acc: 0.5928 - val_loss: 0.6449 - val_acc: 0.6676 - 954ms/epoch - 48ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.6670 - acc: 0.6254 - val_loss: 0.6246 - val_acc: 0.6948 - 76ms/epoch - 4ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.6589 - acc: 0.6433 - val_loss: 0.6100 - val_acc: 0.7166 - 78ms/epoch - 4ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.6531 - acc: 0.6547 - val_loss: 0.5973 - val_acc: 0.7411 - 79ms/epoch - 4ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.6487 - acc: 0.6678 - val_loss: 0.5865 - val_acc: 0.7684 - 72ms/epoch - 4ms/step
# Epoch 6/200
# Epoch 199/200
# 20/20 - 0s - loss: 0.5070 - acc: 0.8111 - val_loss: 0.3626 - val_acc: 0.9428 - 122ms/epoch - 6ms/step
# Epoch 200/200
# 20/20 - 0s - loss: 0.5069 - acc: 0.8111 - val_loss: 0.3609 - val_acc: 0.9401 - 80ms/epoch - 4ms/step

# %% [markdown]
# **Kết quả mong đợi:** Kết quả này là tương đối tuy nhiên mong muốn mô hình sẽ có độ chính xác trên tập validation hơn 90%
#
# ```
# Epoch 197/200
# 20/20 - 0s - loss: 0.5038 - acc: 0.8046 - val_loss: 0.3587 - val_acc: 0.9455
# Epoch 198/200
# 20/20 - 0s - loss: 0.5035 - acc: 0.8062 - val_loss: 0.3593 - val_acc: 0.9455
# Epoch 199/200
# 20/20 - 0s - loss: 0.5033 - acc: 0.8078 - val_loss: 0.3581 - val_acc: 0.9455
# Epoch 200/200
# 20/20 - 0s - loss: 0.5031 - acc: 0.8078 - val_loss: 0.3573 - val_acc: 0.9455
# ```

# %% [markdown]
# ### 12. Đánh giá chất lượng mô hình - Nâng cao - tham khảo thêm
#
# Các chỉ số này sẽ được giảng dạy chi tiết trong các bài học tiếp theo. Mục đích của phần này cho chúng ta thấy vấn đề mất cân bằng dữ liệu.
#
# Đọc thêm về các chỉ số này [tại đây](https://classroom.google.com/c/Mzg3NDIzMjExOTQ5/m/NDMzNjkzMzAyNjA2/details)

# %% [markdown]
# ### 12.1 Tính Precision, Recall và F1 Score
# Thực hiện trên cả nhãn Positive và Negative

# %%
y_pred = (model.predict(val_X) >= 0.5).astype(int)

target_names = ['NO', 'YES']

from sklearn.metrics import classification_report
print(classification_report(
    val_Y, y_pred, target_names=target_names
))

y_pred.shape
# Out:
# 12/12 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#           NO       0.98      0.73      0.84        77
#          YES       0.93      1.00      0.96       290
#
#     accuracy                           0.94       367
#    macro avg       0.96      0.86      0.90       367
# weighted avg       0.94      0.94      0.94       367
# (367, 1)

# %%
from sklearn.metrics import confusion_matrix
TN, FP, FN, TP = confusion_matrix(val_Y, y_pred).ravel()

# %%
TP, FP, TN, FN
# Out:
# (289, 21, 56, 1)

# %%
# Positive Precision

TP / (TP + FP)
# Out:
# 0.932258064516129

# %%
# Positive Recall

TP / (TP + FN)
# Out:
# 0.996551724137931

# %%
# Negative Precision

TN / (TN + FN)
# Out:
# 0.9824561403508771

# %%
# Negative Recall

TN / (TN + FP)
# Out:
# 0.7272727272727273

# %% [markdown]
# Nhận thấy Negative Recall tương đối thấp vì có sự mất cân bằng của dự liệu giữa nhãn `YES` và `NO`

# %%
train_df['Loan_Status'].value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %% [markdown]
# Cách giải quyết đơn giản nhất hiện tượng này là oversampling hoặc undersampling. Xem thêm [tại đây](https://github.com/scikit-learn-contrib/imbalanced-learn).

# %% [markdown]
# -------------------- Kết thúc --------------------

# %% [markdown]
# <img src='https://storage.googleapis.com/protonx-cloud-storage/icons/1103-confetti-outline.gif' width=200>
